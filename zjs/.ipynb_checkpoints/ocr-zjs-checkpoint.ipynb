# %%
# coding: utf-8
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
import pyperclip
import time
import os
from PIL import Image

# %%
PROV_FROM = [u'江苏省-南京市-栖霞区', u'广东省-广州市-花都区',u'天津市-天津市-东丽区', u'陕西省-西安市-新城区', u'四川省-成都市-龙泉驿区']

class Dstfee(object):

    """docstring for ClassName"""

    def __init__(self, url, addressfrom):
        # PROV_FROM = [u"广东", u"江苏", u"陕西", u"四川", u"天津"]
        # PROV_TO = [u"安徽", u"北京", u"福建", u"甘肃", u"广东", u"广西", u"贵州", u"海南", u"河北", u"河南", u"黑龙江", u"湖北", u"湖南", u"吉林", u"江苏", u"江西", u"辽宁", u"内蒙古", u"宁夏", u"青海", u"山东", u"山西", u"陕西", u"上海", u"四川", u"天津", u"西藏", u"新疆", u"云南", u"浙江", u"重庆"]
        self.url = url
        self.driver = webdriver.Chrome('./chromedriver')
        self.addressfrom = addressfrom
        self.PROV_TO = [arrivedCityName.strip() for arrivedCityName in open('zjsprovn', 'rb').readlines()]

    def extract_and_ocr(self,dst,leftx,lefty,width,height):
        image_file = 'screenshot.png'
        img = Image.open(image_file)
        box = (leftx,lefty, leftx+width, lefty+height)
        img = img.crop(box)
        img.save('captcha.png')
        tatt=os.popen("./rpred.py -Q 4 -m %s.pyrnn.gz captcha.png" % dst)
        return tatt.read()[-5:-1]

    def getfeeems(self,addressfrom, addressto):
        Select(self.driver.find_element_by_id("addressfrom")
               ).select_by_value(addressfrom)
        Select(self.driver.find_element_by_id("addressto")
               ).select_by_value(addressto)
        self.driver.find_element_by_name("weight").clear()
        self.driver.find_element_by_name("weight").send_keys("1")
        self.driver.find_element_by_class_name('table_btn').click()
        ft = self.driver.find_element_by_name("result")
        ft.send_keys(Keys.CONTROL, 'a')
        ft.send_keys(Keys.CONTROL, 'c')
        ft.send_keys(Keys.CONTROL, 'a')
        ft.send_keys(Keys.CONTROL, 'c')
        return pyperclip.paste()

    def getfeeydkd(self,addressfrom, addressto):
        Select(self.driver.find_element_by_id("is_air")).select_by_visible_text(u"非航空件")
        Select(self.driver.find_element_by_id("sfd")).select_by_visible_text(addressfrom)
        Select(self.driver.find_element_by_id("mdd")).select_by_visible_text(addressto)
        self.driver.find_element_by_name("zl").clear()
        self.driver.find_element_by_name("zl").send_keys("1")
        self.driver.find_element_by_xpath(u"//input[@value='查 询']").click()
        ft = self.driver.find_element_by_id("fy")
        return ft.text[:2]

    def getfeedb(self,addressfrom, addressto):
        self.driver.find_element_by_id("leavedCityName").clear()
        self.driver.find_element_by_id("leavedCityName").send_keys(addressfrom)
        self.driver.find_element_by_id("arrivedCityName").clear()
        self.driver.find_element_by_id("arrivedCityName").send_keys(addressto)
        self.driver.find_element_by_xpath(u"//input[@value='查询']").click()
        try:
            ft = self.driver.find_elements_by_class_name("td_fir")
        except NoSuchElementException:
            return 'None'
        else:
            temp = [x.text for x in ft]
            return str(temp[-1]) if len(temp) == 4 else 'None'
        
    def getfeezjs(self,addressfrom, addressto):
        def tempcapchar():
            self.driver.save_screenshot('screenshot.png')
            dst,leftx,lefty,width,height = 'zjs',470,565,60,20
#             code = self.extract_and_ocr(dst,leftx,lefty,width,height)
            code = raw_input('capchar?')
            self.driver.find_element_by_id("ValidateTxt").clear()
            self.driver.find_element_by_id("ValidateTxt").send_keys(code)
            self.driver.find_element_by_id("Button1").click()

        addressfrom_prv, addressfrom_cty, addressfrom_are = addressfrom.split('-')
        addressto_prv, addressto_cty, addressto_are = addressto.split('-')
        Select(self.driver.find_element_by_id("ctl00_Content1_Price_Province")).select_by_visible_text(addressfrom_prv)
        Select(self.driver.find_element_by_id("City")).select_by_visible_text(addressfrom_cty)
        Select(self.driver.find_element_by_id("Area")).select_by_visible_text(addressfrom_are)
        Select(self.driver.find_element_by_id("ctl00_Content1_Price_RProvince")).select_by_visible_text(addressto_prv)
        Select(self.driver.find_element_by_id("RCity")).select_by_visible_text(addressto_cty)
        if addressto_are != 'None':
            Select(self.driver.find_element_by_id("RArea")).select_by_visible_text(addressto_are)
        self.driver.find_element_by_id("ctl00_Content1_Price_ZhongLiang").clear()
        self.driver.find_element_by_id("ctl00_Content1_Price_ZhongLiang").send_keys("1")
        tempcapchar()
        while True:
            try:
                lufei = self.driver.find_element_by_xpath('//*[@id="Result"]/font')
            except NoSuchElementException:
                break
            else:
                time.sleep(1)
                if u'本公司暂未开通两地间快递服务' in lufei.text: return 'None'
                else: tempcapchar()
        def tryfee(k):
            try:
                ft = self.driver.find_element_by_xpath('//*[@id="Result"]/table/tbody/tr[%s]/td[4]' % k)
                return ft.text
            except NoSuchElementException:
                return 'None'
        if tryfee('3') != 'None':return tryfee('3')
        elif tryfee('2') != 'None':return tryfee('2')
        else:return 'None'

    def feeoutput(self,fname,fee):
        def getfeex(addressto):
            self.driver.implicitly_wait(3)
            addressto = unicode(addressto.decode("utf-8"))
            self.driver.get(self.url)
            fees = fee(self.addressfrom, addressto)
            return fees
        for idx,addressto in enumerate(self.PROV_TO):
            fees = getfeex(addressto)
            print idx+1, addressto, fees


def main():
        def last(add):
          url = "http://www.zjs.com.cn/WS_Business/WS_Business_price_internal.aspx?id=6"
          dstfee = Dstfee(url,add)
          dstfee.feeoutput('dst_fee_zjs.txt', dstfee.getfeezjs)
        map(last,PROV_FROM[2:])

if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6db7c88957be> in <module>()
#     122
#     123 if __name__ == '__main__':
# --> 124     main()
#
# <ipython-input-5-6db7c88957be> in main()
#     119           dstfee = Dstfee(url,add)
#     120           dstfee.feeoutput('dst_fee_zjs.txt', dstfee.getfeezjs)
# --> 121         map(last,PROV_FROM[2:])
#     122
#     123 if __name__ == '__main__':
#
# <ipython-input-5-6db7c88957be> in last(add)
#     118           url = "http://www.zjs.com.cn/WS_Business/WS_Business_price_internal.aspx?id=6"
#     119           dstfee = Dstfee(url,add)
# --> 120           dstfee.feeoutput('dst_fee_zjs.txt', dstfee.getfeezjs)
#     121         map(last,PROV_FROM[2:])
#     122
#
# <ipython-input-5-6db7c88957be> in feeoutput(self, fname, fee)
#     110             return fees
#     111         for idx,addressto in enumerate(self.PROV_TO):
# --> 112             fees = getfeex(addressto)
#     113             print idx+1, addressto, fees
#     114
#
# <ipython-input-5-6db7c88957be> in getfeex(addressto)
#     107             addressto = unicode(addressto.decode("utf-8"))
#     108             self.driver.get(self.url)
# --> 109             fees = fee(self.addressfrom, addressto)
#     110             return fees
#     111         for idx,addressto in enumerate(self.PROV_TO):
#
# <ipython-input-5-6db7c88957be> in getfeezjs(self, addressfrom, addressto)
#      91                 time.sleep(1)
#      92                 if u'本公司暂未开通两地间快递服务' in lufei.text: return 'None'
# ---> 93                 else: tempcapchar()
#      94         def tryfee(k):
#      95             try:
#
# <ipython-input-5-6db7c88957be> in tempcapchar()
#      65             self.driver.save_screenshot('screenshot.png')
#      66             dst,leftx,lefty,width,height = 'zjs',470,565,60,20
# ---> 67             code = self.extract_and_ocr(dst,leftx,lefty,width,height)
#      68 #             code = raw_input('capchar?')
#      69             self.driver.find_element_by_id("ValidateTxt").clear()
#
# <ipython-input-5-6db7c88957be> in extract_and_ocr(self, dst, leftx, lefty, width, height)
#      20         img.save('captcha.png')
#      21         tatt=os.popen("./rpred.py -Q 4 -m %s.pyrnn.gz captcha.png" % dst)
# ---> 22         return tatt.read()[-5:-1]
#      23
#      24     def getfeeems(self,addressfrom, addressto):
#
# KeyboardInterrupt:
